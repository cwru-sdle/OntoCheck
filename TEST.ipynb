# %%
# In the first cell of test.ipynb

import sys
import os

# Get the absolute path to the 'src' directory
# os.getcwd() gives the current directory (where the notebook is)
# os.path.join combines it into a full path
src_path = os.path.join(os.getcwd(), 'src')

# Add the 'src' path to the Python path if it's not already there
if src_path not in sys.path:
    sys.path.append(src_path)
    print(f"Added {src_path} to Python path")

# Now you can import your modules
print("Ready to import from Onto_Assessment.")
# Out:
# Added /home/redad/Git/Ontology-Assessment/src to Python path
# Ready to import from Onto_Assessment.

# %%
from Onto_Assessment.find_duplicate_labels_from_graph import find_duplicate_labels_from_graph

# %%
ttl = "/home/redad/Downloads/Ontology-TurtleFiles/recipe.ttl"

# %%
duplicates = find_duplicate_labels_from_graph(ttl)
duplicates

# %%
from Onto_Assessment.check_for_isolated_elements import *

isolated_elements = check_for_isolated_elements(ttl)
isolated_elements
# Out:
# [INFO] Added atomic class: https://cwrusdle.bitbucket.io/mds/BeamStopTransversePosition
# [INFO] Added atomic class: https://cwrusdle.bitbucket.io/mds/DetectorZOrientation
# [INFO] Added atomic class: http://purl.obolibrary.org/obo/BFO_0000015
# [INFO] Added atomic class: https://cwrusdle.bitbucket.io/mds/SampleYPosition
# [INFO] Added atomic class: https://cwrusdle.bitbucket.io/mds/DetectorCalibration
# [INFO] Added atomic class: https://cwrusdle.bitbucket.io/mds/MonochromatorOffset
# [INFO] Added atomic class: https://cwrusdle.bitbucket.io/mds/MonochromatorRotation
# [INFO] Added atomic class: https://cwrusdle.bitbucket.io/mds/PONIFile
# [INFO] Added atomic class: https://cwrusdle.bitbucket.io/mds/DetectorXOrientation
# [INFO] Added atomic class: https://cwrusdle.bitbucket.io/mds/SlitVerticalBladesTopPosition
# [INFO] Added atomic class: https://www.commoncoreontologies.org/ont00000995
# [INFO] Added atomic class: https://cwrusdle.bitbucket.io/mds/EnergyCalibrationFoilPosition
# ...

# %%
from Onto_Assessment.run_assessment import *

ttl = "/home/redad/Downloads/Ontology-TurtleFiles/recipe.ttl"

run_ontology_assessment(
    ttl,
    metrics="all",
    output_log_file="out.log",
    output_csv_file="out.csv"
)
# Out:
# Running all available metrics.
# --- Starting ontology assessment for: /home/redad/Downloads/Ontology-TurtleFiles/recipe.ttl ---
# Metrics to run: altLabelCheck, externalLinks, isolatedElements, humanLicense, rdfDump, sparqlEndpoint, classConnections, definitionCheck, duplicateLabels, missingDomainRange, leafNodeCheck, semanticConnection
# --- Running Metric: altLabelCheck ---
# Parsing file: /home/redad/Downloads/Ontology-TurtleFiles/recipe.ttl...
# Found 55 unique named classes.
#
# --- SKOS Definition Coverage Summary ---
# Total classes analyzed: 55
# Classes with definitions: 32 (58.2%)
# Classes without definitions: 23 (41.8%)
#
# Assessment: Moderate definition coverage
#
# --- Classes WITH altLabel (32) ---
#
# Class: mds:AttenuatorWheelsPosition
#   Preferred Label: Attenuator wheel position
#   Alternative Labels (2):
#     - "att"
#     - "attf"
#
# Class: mds:BeamStopRotation
#   Preferred Label: beam stop rotation
#   Alternative Labels (1):
#     - "bsr"
#
# ...
